# %%
import pandas as pd 
# !pip install xlrd

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# data = pd.read_excel("iris.xlsx")

# %%
# First make sure you have the openpyxl package installed
# You can install it using: pip install openpyxl

import pandas as pd

# Explicitly specify the engine as 'openpyxl' for xlsx files
data = pd.read_excel("train iris.xlsx", engine='openpyxl')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-32-399ea97ad831> in <module>
#       5
#       6 # Explicitly specify the engine as 'openpyxl' for xlsx files
# ----> 7 data = pd.read_excel("train iris.xlsx", engine='openpyxl')
#
# ~\anaconda3\envs\bookenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
data
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]
